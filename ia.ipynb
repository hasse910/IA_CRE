# %% [markdown]
# <a href="https://colab.research.google.com/github/hasse910/IA_CRE/blob/main/ia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# !pip -q install aiohttp pyngrok
# Out:
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
import os
import asyncio

# Certifique-se de que userdata está importado, por exemplo:
from google.colab import userdata

# Configurações iniciais
os.environ.update({'LD_LIBRARY_PATH': '/usr/lib64-nvidia'})
os.environ['OLLAMA_ORIGINS'] = '*' # Ou 'https://*.ngrok-free.app'

# !!! Verifique se ngrok_key está sendo obtido corretamente !!!
# Se userdata.get('ngrok_key') retornar None, os comandos ngrok podem falhar silenciosamente
# ou se comportar de forma inesperada.
ngrok_key = userdata.get('ngrok_key')
print(f"--- DEBUG: Valor de ngrok_key carregado: '{ngrok_key}' ---") # LINHA DE DEBUG
if not ngrok_key:
    print("AVISO: Chave do ngrok (ngrok_key) não encontrada no userdata!")
    # Você pode querer parar aqui ou usar um valor padrão se aplicável,
    # ou prosseguir sabendo que o ngrok pode não funcionar.

# Evento para sinalizar que o servidor Ollama está pronto
ollama_ready_event = asyncio.Event()

async def run_process_wrapper(cmd, is_server=False, ready_signal_in_log=None,
                              event_to_set_on_ready=None, event_to_wait_for=None,
                              suppress_ngrok_key_in_cmd_print=True):
    """
    Executa um comando e gerencia a espera/sinalização de prontidão.
    """
    global ngrok_key # Acessa a variável global ngrok_key

    if event_to_wait_for:
        print(f">>> '{cmd[0]}' esperando pelo evento de prontidão...")
        await event_to_wait_for.wait()
        print(f">>> Evento recebido, iniciando '{cmd[0]}'.")

    cmd_display_parts = []
    if suppress_ngrok_key_in_cmd_print and ngrok_key:
        for part in cmd:
            if part == ngrok_key:
                cmd_display_parts.append("[NGROK_KEY_OCULTA]")
            else:
                cmd_display_parts.append(part)
    else:
        cmd_display_parts = list(cmd)
    cmd_display_name = " ".join(cmd_display_parts)

    print(f'>>> starting {cmd_display_name}')

    p = await asyncio.subprocess.create_subprocess_exec(
        *cmd,
        stdout=asyncio.subprocess.PIPE,
        stderr=asyncio.subprocess.PIPE,
    )

    async def pipe(stream, stream_name_suffix): # Esta é a função interna de run_process_wrapper
      # cmd é acessado do escopo externo de run_process_wrapper
      # ngrok_key também é acessado do escopo global/externo

      stream_name = f"{cmd[0]} {stream_name_suffix}"
      is_ngrok_stderr_pipe = (cmd[0] == 'ngrok' and 'http' in cmd and stream_name_suffix == 'stderr')

      if is_ngrok_stderr_pipe:
          print(f"--- DEBUG PIPE: Iniciando pipe para ngrok stderr ---")

      async for line_bytes in stream:
          line = line_bytes.decode('utf-8', errors='replace').strip()

          # Lógica de formatação do log (pode manter a sua ou simplificar para debug)
          log_line_display = f"[{stream_name}]: {line}"
          # Se quiser re-adicionar a lógica de ocultar chave:
          # if suppress_ngrok_key_in_cmd_print and ngrok_key and ngrok_key in line:
          #     log_line_display = f"[{stream_name}]: [linha contendo NGROK_KEY ocultada]"
          # else:
          #     log_line_display = f"[{stream_name}]: {line}"

          if is_ngrok_stderr_pipe:
              print(f"--- DEBUG NGROK STDERR RAW: '{line}' ---") # Mostra a linha crua do ngrok stderr
              if "url=" in line: # Procura pela parte da URL
                  print(f"--- DEBUG NGROK URL LINE DETECTED: '{line}' ---")

          print(log_line_display) # Imprime a linha de log formatada para todos os processos

          # Lógica de sinalização de evento (mantenha como estava)
          if is_server and ready_signal_in_log and ready_signal_in_log in line:
              if event_to_set_on_ready and not event_to_set_on_ready.is_set():
                  print(f">>> SERVIDOR '{cmd[0]}' ESTÁ PRONTO! (viu: '{ready_signal_in_log}')")
                  event_to_set_on_ready.set()

      if is_ngrok_stderr_pipe:
          print(f"--- DEBUG PIPE: Finalizando pipe para ngrok stderr ---")

    # Estas tasks rodam até o processo terminar ou serem canceladas.
    stdout_task = asyncio.create_task(pipe(p.stdout, 'stdout'))
    stderr_task = asyncio.create_task(pipe(p.stderr, 'stderr'))

    try:
        # Espera o processo terminar e as tasks de pipe também.
        # Se uma task de pipe falhar, ou o processo terminar, gather retornará.
        await asyncio.gather(stdout_task, stderr_task)
        # Espera explicitamente pelo processo para garantir que o código de retorno seja registrado.
        await p.wait()
    except asyncio.CancelledError:
        print(f">>> Tarefa para '{cmd_display_name}' foi cancelada.")
        # Garante que o processo filho seja terminado se a task principal for cancelada
        if p.returncode is None: # Se o processo ainda estiver rodando
            print(f">>> Tentando terminar o processo '{cmd_display_name}'...")
            p.terminate()
            await p.wait() # Espera a terminação
        raise # Re-levanta CancelledError para que gather possa lidar com ela
    except Exception as e:
        print(f"Erro inesperado ao executar '{cmd_display_name}': {e}")
        if p.returncode is None:
            p.terminate()
            await p.wait()
    finally:
        # Garante que as tasks de pipe sejam canceladas se ainda estiverem rodando
        # (por exemplo, se p.wait() retornou mas as tasks de pipe não por algum motivo)
        if not stdout_task.done(): stdout_task.cancel()
        if not stderr_task.done(): stderr_task.cancel()
        # Espera que as tasks de pipe realmente terminem após o cancelamento
        await asyncio.gather(stdout_task, stderr_task, return_exceptions=True)

        print(f">>> '{cmd_display_name}' finalizado com código {p.returncode if p.returncode is not None else 'N/A (possivelmente cancelado)'}.")
        if is_server and event_to_set_on_ready and not event_to_set_on_ready.is_set():
            print(f"ATENÇÃO: Servidor '{cmd[0]}' terminou antes de sinalizar prontidão ou foi cancelado.")
            event_to_set_on_ready.set() # Desbloqueia outros para evitar deadlock, mesmo que falhem


async def main():
    global ngrok_key # Permite que main acesse a variável ngrok_key
    if not ngrok_key:
        print("Chave do ngrok não definida. O túnel ngrok não será iniciado corretamente.")
        # Decide se quer parar ou continuar sem ngrok. Para este exemplo, vamos prosseguir.

    # 1. Configurar o token do ngrok primeiro (comando que termina)
    # Só executa se ngrok_key estiver definida
    if ngrok_key:
        await run_process_wrapper(
            ['ngrok', 'config', 'add-authtoken', ngrok_key],
            suppress_ngrok_key_in_cmd_print=True
        )
    else:
        print("Pular configuração do authtoken do ngrok pois a chave não foi fornecida.")


    # 2. Iniciar todos os outros processos concorrentemente,
    #    mas com dependência de prontidão para ollama pull e ngrok.
    try:
        await asyncio.gather(
            run_process_wrapper(
                ['ollama', 'serve'],
                is_server=True,
                ready_signal_in_log="Listening on 127.0.0.1:11434", # Sinal de prontidão
                event_to_set_on_ready=ollama_ready_event      # Evento a ser sinalizado
            ),
            run_process_wrapper(
                ['ollama', 'pull', 'gemma3:4b'],
                event_to_wait_for=ollama_ready_event          # Espera pelo ollama serve
            ),
            # Só executa ngrok http se ngrok_key estiver definida, caso contrário, o comando falharia
            run_process_wrapper(
                ['ngrok', 'http', '--log', 'stderr', '11434'],
                event_to_wait_for=ollama_ready_event,         # Também espera pelo ollama serve
                suppress_ngrok_key_in_cmd_print=False
            ) if ngrok_key else asyncio.sleep(0) # Se não houver chave, não faz nada com ngrok http
        )
    except asyncio.CancelledError:
        print("Execução principal (main gather) foi cancelada.")
    except Exception as e:
        print(f"Erro na execução principal (main gather): {e}")



# Para executar no Colab (ou em um ambiente com loop de eventos já rodando):
# await main()

# Ou, se for um script Python puro ou se o await main() não funcionar:
# asyncio.run(main())

# Exemplo de como chamar no Colab, lidando com loop de eventos existente:
# loop = asyncio.get_event_loop()
# if loop.is_running():
#     print("Loop de eventos asyncio já está rodando. Criando task para main().")
#     loop.create_task(main())
# else:
#     print("Iniciando novo loop de eventos asyncio para main().")
#     asyncio.run(main())

# (Todo o seu código anterior: imports, ngrok_key, ollama_ready_event, run_process_wrapper, main, etc. permanece o mesmo)
# ...
# async def main():
#    ... (corpo da sua função main) ...
# ...

# 👇 MODIFIQUE ESTA PARTE FINAL PARA USAR 'await main()' 👇
print("--- SCRIPT: Iniciando execução de main() com await ---")
try:
    await main() # A mudança principal é aqui!
except KeyboardInterrupt:
    print("--- SCRIPT: Execução interrompida pelo usuário (KeyboardInterrupt) ---")
except Exception as e:
    print(f"--- SCRIPT: Erro fatal ao executar main(): {e} ---")
    import traceback
    traceback.print_exc()
finally:
    print("--- SCRIPT: Execução de main() finalizada (ou tentou finalizar). ---")
# Out:
# --- DEBUG: Valor de ngrok_key carregado: '2xyQZ0B07aUR5DmPRtPLEWlRGa2_8163Tahir1m121RJqPtXh' ---
# --- SCRIPT: Iniciando execução de main() com await ---
# >>> starting ngrok config add-authtoken [NGROK_KEY_OCULTA]
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# >>> 'ngrok config add-authtoken [NGROK_KEY_OCULTA]' finalizado com código 0.
# >>> starting ollama serve
# >>> 'ollama' esperando pelo evento de prontidão...
# >>> 'ngrok' esperando pelo evento de prontidão...
# [ollama stdout]: Couldn't find '/root/.ollama/id_ed25519'. Generating new private key.
# [ollama stdout]: Your new public key is:
# [ollama stdout]:
# [ollama stdout]: ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAIAvz7C5ncrZUn/7Y154OBS+tLpmzdDa5Dxt7QUSxNsRP
# [ollama stdout]:
# [ollama stderr]: time=2025-06-03T00:37:10.565Z level=INFO source=routes.go:1234 msg="server config" env="map[CUDA_VISIBLE_DEVICES: GPU_DEVICE_ORDINAL: HIP_VISIBLE_DEVICES: HSA_OVERRIDE_GFX_VERSION: HTTPS_PROXY: HTTP_PROXY: NO_PROXY: OLLAMA_CONTEXT_LENGTH:4096 OLLAMA_DEBUG:INFO OLLAMA_FLASH_ATTENTION:false OLLAMA_GPU_OVERHEAD:0 OLLAMA_HOST:http://127.0.0.1:11434 OLLAMA_INTEL_GPU:false OLLAMA_KEEP_ALIVE:5m0s OLLAMA_KV_CACHE_TYPE: OLLAMA_LLM_LIBRARY: OLLAMA_LOAD_TIMEOUT:5m0s OLLAMA_MAX_LOADED_MODELS:0 OLLAMA_MAX_QUEUE:512 OLLAMA_MODELS:/root/.ollama/models OLLAMA_MULTIUSER_CACHE:false OLLAMA_NEW_ENGINE:false OLLAMA_NOHISTORY:false OLLAMA_NOPRUNE:false OLLAMA_NUM_PARALLEL:0 OLLAMA_ORIGINS:[* http://localhost https://localhost http://localhost:* https://localhost:* http://127.0.0.1 https://127.0.0.1 http://127.0.0.1:* https://127.0.0.1:* http://0.0.0.0 https://0.0.0.0 http://0.0.0.0:* https://0.0.0.0:* app://* file://* tauri://* vscode-webview://* vscode-file://*] OLLAMA_SCHED_SPREAD:false ROCR_VISIBLE_DEVICES: http_proxy: https_proxy: no_proxy:]"
# [ollama stderr]: time=2025-06-03T00:37:10.569Z level=INFO source=images.go:479 msg="total blobs: 0"
# [ollama stderr]: time=2025-06-03T00:37:10.569Z level=INFO source=images.go:486 msg="total unused blobs removed: 0"
# [ollama stderr]: time=2025-06-03T00:37:10.569Z level=INFO source=routes.go:1287 msg="Listening on 127.0.0.1:11434 (version 0.9.0)"
# >>> SERVIDOR 'ollama' ESTÁ PRONTO! (viu: 'Listening on 127.0.0.1:11434')
# >>> Evento recebido, iniciando 'ollama'.
# >>> starting ollama pull gemma3:4b
# >>> Evento recebido, iniciando 'ngrok'.
# >>> starting ngrok http --log stderr 11434
# [ollama stderr]: time=2025-06-03T00:37:10.571Z level=INFO source=gpu.go:217 msg="looking for compatible GPUs"
# --- DEBUG PIPE: Iniciando pipe para ngrok stderr ---
# [ollama stderr]: time=2025-06-03T00:37:10.648Z level=INFO source=gpu.go:377 msg="no compatible GPUs were discovered"
# [ollama stderr]: time=2025-06-03T00:37:10.649Z level=INFO source=types.go:130 msg="inference compute" id=0 library=cpu variant="" compute="" driver=0.0 name="" total="12.7 GiB" available="11.6 GiB"
# [ollama stdout]: [GIN] 2025/06/03 - 00:37:10 | 200 |     838.724µs |       127.0.0.1 | HEAD     "/"
# --- DEBUG NGROK STDERR RAW: 't=2025-06-03T00:37:10+0000 lvl=info msg="no configuration paths supplied"' ---
# [ngrok stderr]: t=2025-06-03T00:37:10+0000 lvl=info msg="no configuration paths supplied"
# --- DEBUG NGROK STDERR RAW: 't=2025-06-03T00:37:10+0000 lvl=info msg="using configuration at default config path" path=/root/.config/ngrok/ngrok.yml' ---
# [ngrok stderr]: t=2025-06-03T00:37:10+0000 lvl=info msg="using configuration at default config path" path=/root/.config/ngrok/ngrok.yml
# --- DEBUG NGROK STDERR RAW: 't=2025-06-03T00:37:10+0000 lvl=info msg="open config file" path=/root/.config/ngrok/ngrok.yml err=nil' ---
# [ngrok stderr]: t=2025-06-03T00:37:10+0000 lvl=info msg="open config file" path=/root/.config/ngrok/ngrok.yml err=nil
# --- DEBUG NGROK STDERR RAW: 't=2025-06-03T00:37:10+0000 lvl=info msg="starting web service" obj=web addr=127.0.0.1:4040 allow_hosts=[]' ---
# [ngrok stderr]: t=2025-06-03T00:37:10+0000 lvl=info msg="starting web service" obj=web addr=127.0.0.1:4040 allow_hosts=[]
# --- DEBUG NGROK STDERR RAW: 't=2025-06-03T00:37:11+0000 lvl=info msg="client session established" obj=tunnels.session' ---
# [ngrok stderr]: t=2025-06-03T00:37:11+0000 lvl=info msg="client session established" obj=tunnels.session
# --- DEBUG NGROK STDERR RAW: 't=2025-06-03T00:37:11+0000 lvl=info msg="tunnel session started" obj=tunnels.session' ---
# [ngrok stderr]: t=2025-06-03T00:37:11+0000 lvl=info msg="tunnel session started" obj=tunnels.session
# --- DEBUG NGROK STDERR RAW: 't=2025-06-03T00:37:11+0000 lvl=info msg="started tunnel" obj=tunnels name=command_line addr=http://localhost:11434 url=https://706d-34-23-40-72.ngrok-free.app' ---
# --- DEBUG NGROK URL LINE DETECTED: 't=2025-06-03T00:37:11+0000 lvl=info msg="started tunnel" obj=tunnels name=command_line addr=http://localhost:11434 url=https://706d-34-23-40-72.ngrok-free.app' ---
# [ngrok stderr]: t=2025-06-03T00:37:11+0000 lvl=info msg="started tunnel" obj=tunnels name=command_line addr=http://localhost:11434 url=https://706d-34-23-40-72.ngrok-free.app
# [ollama stderr]: time=2025-06-03T00:37:11.340Z level=INFO source=download.go:177 msg="downloading aeda25e63ebd in 16 208 MB part(s)"
# [ollama stderr]: pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest
# [ollama stderr]: pulling aeda25e63ebd:   0% ▕                  ▏ 9.8 MB/3.3 GB                  pulling manifest
# [ollama stderr]: pulling aeda25e63ebd:   1% ▕                  ▏  19 MB/3.3 GB                  pulling manifest
# [ollama stderr]: pulling aeda25e63ebd:   1% ▕                  ▏  36 MB/3.3 GB                  pulling manifest
# [ollama stderr]: pulling aeda25e63ebd:   2% ▕                  ▏  58 MB/3.3 GB                  pulling manifest
# [ollama stderr]: pulling aeda25e63ebd:   2% ▕                  ▏  66 MB/3.3 GB                  pulling manifest
# [ollama stderr]: pulling aeda25e63ebd:   3% ▕                  ▏  84 MB/3.3 GB                  pulling manifest
# [ollama stderr]: pulling aeda25e63ebd:   3% ▕                  ▏  89 MB/3.3 GB                  pulling manifest
# [ollama stderr]: pulling aeda25e63ebd:   3% ▕                  ▏ 104 MB/3.3 GB                  pulling manifest
# [ollama stderr]: pulling aeda25e63ebd:   3% ▕                  ▏ 116 MB/3.3 GB                  pulling manifest
# [ollama stderr]: pulling aeda25e63ebd:   4% ▕                  ▏ 131 MB/3.3 GB                  pulling manifest
# [ollama stderr]: pulling aeda25e63ebd:   4% ▕                  ▏ 137 MB/3.3 GB  136 MB/s     23spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:   4% ▕                  ▏ 144 MB/3.3 GB  136 MB/s     23spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:   5% ▕                  ▏ 166 MB/3.3 GB  136 MB/s     23spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:   5% ▕                  ▏ 171 MB/3.3 GB  136 MB/s     23spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:   5% ▕                  ▏ 180 MB/3.3 GB  136 MB/s     23spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:   6% ▕█                 ▏ 189 MB/3.3 GB  136 MB/s     23spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:   6% ▕█                 ▏ 196 MB/3.3 GB  136 MB/s     23spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:   6% ▕█                 ▏ 206 MB/3.3 GB  136 MB/s     22spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:   7% ▕█                 ▏ 221 MB/3.3 GB  136 MB/s     22spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:   7% ▕█                 ▏ 226 MB/3.3 GB  136 MB/s     22spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:   7% ▕█                 ▏ 231 MB/3.3 GB  115 MB/s     26spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:   7% ▕█                 ▏ 235 MB/3.3 GB  115 MB/s     26spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:   7% ▕█                 ▏ 236 MB/3.3 GB  115 MB/s     26spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:   7% ▕█                 ▏ 237 MB/3.3 GB  115 MB/s     26spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:   7% ▕█                 ▏ 238 MB/3.3 GB  115 MB/s     26spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:   7% ▕█                 ▏ 238 MB/3.3 GB  115 MB/s     26spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:   7% ▕█                 ▏ 239 MB/3.3 GB  115 MB/s     26spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:   7% ▕█                 ▏ 239 MB/3.3 GB  115 MB/s     26spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:   7% ▕█                 ▏ 239 MB/3.3 GB  115 MB/s     26spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:   7% ▕█                 ▏ 249 MB/3.3 GB  115 MB/s     26spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:   8% ▕█                 ▏ 263 MB/3.3 GB   87 MB/s     35spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:   8% ▕█                 ▏ 271 MB/3.3 GB   87 MB/s     35spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:
ulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  68% ▕████████████      ▏ 2.3 GB/3.3 GB   90 MB/s     11spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  68% ▕████████████      ▏ 2.3 GB/3.3 GB   90 MB/s     11spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  68% ▕████████████      ▏ 2.3 GB/3.3 GB   90 MB/s     11spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  68% ▕████████████      ▏ 2.3 GB/3.3 GB   90 MB/s     11spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  68% ▕████████████      ▏ 2.3 GB/3.3 GB   90 MB/s     11spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  68% ▕████████████      ▏ 2.3 GB/3.3 GB   90 MB/s     11spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  68% ▕████████████      ▏ 2.3 GB/3.3 GB   90 MB/s     11spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  68% ▕████████████      ▏ 2.3 GB/3.3 GB   90 MB/s     11spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  68% ▕████████████      ▏ 2.3 GB/3.3 GB   78 MB/s     13spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  68% ▕████████████      ▏ 2.3 GB/3.3 GB   78 MB/s     13spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  68% ▕████████████      ▏ 2.3 GB/3.3 GB   78 MB/s     13spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  68% ▕████████████      ▏ 2.3 GB/3.3 GB   78 MB/s     13spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  68% ▕████████████      ▏ 2.3 GB/3.3 GB   78 MB/s     13spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  68% ▕████████████      ▏ 2.3 GB/3.3 GB   78 MB/s     13spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  68% ▕████████████      ▏ 2.3 GB/3.3 GB   78 MB/s     13spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  68% ▕████████████      ▏ 2.3 GB/3.3 GB   78 MB/s     13spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  68% ▕████████████      ▏ 2.3 GB/3.3 GB   78 MB/s     13spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  68% ▕████████████      ▏ 2.3 GB/3.3 GB   78 MB/s     13spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  68% ▕████████████      ▏ 2.3 GB/3.3 GB   61 MB/s     17spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  68% ▕████████████      ▏ 2.3 GB/3.3 GB   61 MB/s     17spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  69% ▕████████████      ▏ 2.3 GB/3.3 GB   61 MB/s     16spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  72% ▕████████████      ▏ 2.4 GB/3.3 GB   61 MB/s     15spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  73% ▕█████████████     ▏ 2.4 GB/3.3 GB   61 MB/s     14spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  73% ▕█████████████     ▏ 2.4 GB/3.3 GB   61 MB/s     14spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  74% ▕█████████████     ▏ 2.5 GB/3.3 GB   61 MB/s     14spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  75% ▕█████████████     ▏ 2.5 GB/3.3 GB   61 MB/s     13spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  76% ▕█████████████     ▏ 2.5 GB/3.3 GB   61 MB/s     12spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   61 MB/s     12spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   79 MB/s      9spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   79 MB/s      9spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   79 MB/s      9spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   79 MB/s      9spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   79 MB/s      9spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   79 MB/s      9spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   79 MB/s      9spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   79 MB/s      9spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   79 MB/s      9spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   79 MB/s      9spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   79 MB/s      9spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   53 MB/s     14spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   53 MB/s     14spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   53 MB/s     14spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   53 MB/s     14spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   53 MB/s     14spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   53 MB/s     14spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   53 MB/s     14spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   53 MB/s     14spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   53 MB/s     14spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   53 MB/s     14spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   31 MB/s     24spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   31 MB/s     24spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   31 MB/s     24spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   31 MB/s     24spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   31 MB/s     24spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   31 MB/s     24spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   31 MB/s     24spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   31 MB/s     24spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   31 MB/s     24spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   31 MB/s     24spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   31 MB/s     24spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   31 MB/s     24spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   31 MB/s     24spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   31 MB/s     24spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   31 MB/s     24spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   31 MB/s     24spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   31 MB/s     24spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   31 MB/s     24spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   31 MB/s     24spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   31 MB/s     24spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   31 MB/s     24spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   31 MB/s     24spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   31 MB/s     24spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   31 MB/s     24spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   31 MB/s     24spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   31 MB/s     24spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   31 MB/s     24spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   31 MB/s     24spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   31 MB/s     24spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   31 MB/s     24spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   32 MB/s     23spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   32 MB/s     23spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB   32 MB/s     23spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  79% ▕██████████████    ▏ 2.7 GB/3.3 GB   32 MB/s     21spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  80% ▕██████████████    ▏ 2.7 GB/3.3 GB   32 MB/s     20spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  81% ▕██████████████    ▏ 2.7 GB/3.3 GB   32 MB/s     19spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  82% ▕██████████████    ▏ 2.7 GB/3.3 GB   32 MB/s     18spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  82% ▕██████████████    ▏ 2.7 GB/3.3 GB   32 MB/s     18spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  83% ▕██████████████    ▏ 2.8 GB/3.3 GB   32 MB/s     17spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  85% ▕███████████████   ▏ 2.8 GB/3.3 GB   32 MB/s     15spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  85% ▕███████████████   ▏ 2.8 GB/3.3 GB   32 MB/s     15spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  86% ▕███████████████   ▏ 2.9 GB/3.3 GB   65 MB/s      6spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  88% ▕███████████████   ▏ 2.9 GB/3.3 GB   65 MB/s      6spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  88% ▕███████████████   ▏ 3.0 GB/3.3 GB   65 MB/s      5spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  90% ▕████████████████  ▏ 3.0 GB/3.3 GB   65 MB/s      5spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  90% ▕████████████████  ▏ 3.0 GB/3.3 GB   65 MB/s      4spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  90% ▕████████████████  ▏ 3.0 GB/3.3 GB   65 MB/s      4spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  90% ▕████████████████  ▏ 3.0 GB/3.3 GB   65 MB/s      4spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  90% ▕████████████████  ▏ 3.0 GB/3.3 GB   65 MB/s      4spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  90% ▕████████████████  ▏ 3.0 GB/3.3 GB   65 MB/s      4spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  90% ▕████████████████  ▏ 3.0 GB/3.3 GB   65 MB/s      4spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  90% ▕████████████████  ▏ 3.0 GB/3.3 GB   81 MB/s      3spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  90% ▕████████████████  ▏ 3.0 GB/3.3 GB   81 MB/s      3spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  90% ▕████████████████  ▏ 3.0 GB/3.3 GB   81 MB/s      3spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  90% ▕████████████████  ▏ 3.0 GB/3.3 GB   81 MB/s      3spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  90% ▕████████████████  ▏ 3.0 GB/3.3 GB   81 MB/s      3spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  90% ▕████████████████  ▏ 3.0 GB/3.3 GB   81 MB/s      3spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  90% ▕████████████████  ▏ 3.0 GB/3.3 GB   81 MB/s      3spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  90% ▕████████████████  ▏ 3.0 GB/3.3 GB   81 MB/s      3spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  90% ▕████████████████  ▏ 3.0 GB/3.3 GB   81 MB/s      3spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  90% ▕████████████████  ▏ 3.0 GB/3.3 GB   81 MB/s      3spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  90% ▕████████████████  ▏ 3.0 GB/3.3 GB   81 MB/s      4spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  90% ▕████████████████  ▏ 3.0 GB/3.3 GB   81 MB/s      4spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  90% ▕████████████████  ▏ 3.0 GB/3.3 GB   81 MB/s      4spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  90% ▕████████████████  ▏ 3.0 GB/3.3 GB   81 MB/s      4spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  90% ▕████████████████  ▏ 3.0 GB/3.3 GB   81 MB/s      4spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  90% ▕████████████████  ▏ 3.0 GB/3.3 GB   81 MB/s      4spulling manifest
# [ollama stderr]: pulling aeda25e63ebd:  90% ▕████████████████  ▏ 3.0 GB/3.3 GB   81 MB/s      4spulling manifest
# ...
# [ollama stderr]: pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# [ollama stderr]: pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# [ollama stderr]: pulling dd084c7d92a3: 100% ▕██████████████████▏ 8.4 KB
# [ollama stderr]: pulling 3116c5225075: 100% ▕██████████████████▏   77 B
# [ollama stderr]: pulling b6ae5839783f: 100% ▕██████████████████▏  489 B
# [ollama stderr]: verifying sha256 digest ⠦ pulling manifest
# [ollama stderr]: pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# [ollama stderr]: pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# [ollama stderr]: pulling dd084c7d92a3: 100% ▕██████████████████▏ 8.4 KB
# [ollama stderr]: pulling 3116c5225075: 100% ▕██████████████████▏   77 B
# [ollama stderr]: pulling b6ae5839783f: 100% ▕██████████████████▏  489 B
# [ollama stderr]: verifying sha256 digest ⠧ pulling manifest
# [ollama stderr]: pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# [ollama stderr]: pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# [ollama stderr]: pulling dd084c7d92a3: 100% ▕██████████████████▏ 8.4 KB
# [ollama stderr]: pulling 3116c5225075: 100% ▕██████████████████▏   77 B
# [ollama stderr]: pulling b6ae5839783f: 100% ▕██████████████████▏  489 B
# [ollama stderr]: verifying sha256 digest ⠇ pulling manifest
# [ollama stderr]: pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# [ollama stderr]: pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# [ollama stderr]: pulling dd084c7d92a3: 100% ▕██████████████████▏ 8.4 KB
# [ollama stderr]: pulling 3116c5225075: 100% ▕██████████████████▏   77 B
# [ollama stderr]: pulling b6ae5839783f: 100% ▕██████████████████▏  489 B
# [ollama stderr]: verifying sha256 digest ⠏ pulling manifest
# [ollama stderr]: pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# [ollama stderr]: pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# [ollama stderr]: pulling dd084c7d92a3: 100% ▕██████████████████▏ 8.4 KB
# [ollama stderr]: pulling 3116c5225075: 100% ▕██████████████████▏   77 B
# [ollama stderr]: pulling b6ae5839783f: 100% ▕██████████████████▏  489 B
# [ollama stderr]: verifying sha256 digest ⠋ pulling manifest
# [ollama stderr]: pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# [ollama stderr]: pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# [ollama stderr]: pulling dd084c7d92a3: 100% ▕██████████████████▏ 8.4 KB
# [ollama stderr]: pulling 3116c5225075: 100% ▕██████████████████▏   77 B
# [ollama stderr]: pulling b6ae5839783f: 100% ▕██████████████████▏  489 B
# [ollama stderr]: verifying sha256 digest ⠙ pulling manifest
# [ollama stderr]: pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# [ollama stderr]: pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# [ollama stderr]: pulling dd084c7d92a3: 100% ▕██████████████████▏ 8.4 KB
# [ollama stderr]: pulling 3116c5225075: 100% ▕██████████████████▏   77 B
# [ollama stderr]: pulling b6ae5839783f: 100% ▕██████████████████▏  489 B
# [ollama stderr]: verifying sha256 digest ⠹ pulling manifest
# [ollama stderr]: pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# [ollama stderr]: pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# [ollama stderr]: pulling dd084c7d92a3: 100% ▕██████████████████▏ 8.4 KB
# [ollama stderr]: pulling 3116c5225075: 100% ▕██████████████████▏   77 B
# [ollama stderr]: pulling b6ae5839783f: 100% ▕██████████████████▏  489 B
# [ollama stderr]: verifying sha256 digest ⠸ pulling manifest
# [ollama stderr]: pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# [ollama stderr]: pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# [ollama stderr]: pulling dd084c7d92a3: 100% ▕██████████████████▏ 8.4 KB
# [ollama stderr]: pulling 3116c5225075: 100% ▕██████████████████▏   77 B
# [ollama stderr]: pulling b6ae5839783f: 100% ▕██████████████████▏  489 B
# [ollama stderr]: verifying sha256 digest ⠼ pulling manifest
# [ollama stderr]: pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# [ollama stderr]: pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# [ollama stderr]: pulling dd084c7d92a3: 100% ▕██████████████████▏ 8.4 KB
# [ollama stderr]: pulling 3116c5225075: 100% ▕██████████████████▏   77 B
# [ollama stderr]: pulling b6ae5839783f: 100% ▕██████████████████▏  489 B
# [ollama stderr]: verifying sha256 digest ⠴ pulling manifest
# [ollama stderr]: pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# [ollama stderr]: pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# [ollama stderr]: pulling dd084c7d92a3: 100% ▕██████████████████▏ 8.4 KB
# [ollama stderr]: pulling 3116c5225075: 100% ▕██████████████████▏   77 B
# [ollama stderr]: pulling b6ae5839783f: 100% ▕██████████████████▏  489 B
# [ollama stderr]: verifying sha256 digest ⠦ pulling manifest
# [ollama stderr]: pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# [ollama stderr]: pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# [ollama stderr]: pulling dd084c7d92a3: 100% ▕██████████████████▏ 8.4 KB
# [ollama stderr]: pulling 3116c5225075: 100% ▕██████████████████▏   77 B
# [ollama stderr]: pulling b6ae5839783f: 100% ▕██████████████████▏  489 B
# [ollama stderr]: verifying sha256 digest ⠧ pulling manifest
# [ollama stderr]: pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# [ollama stderr]: pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# [ollama stderr]: pulling dd084c7d92a3: 100% ▕██████████████████▏ 8.4 KB
# [ollama stderr]: pulling 3116c5225075: 100% ▕██████████████████▏   77 B
# [ollama stderr]: pulling b6ae5839783f: 100% ▕██████████████████▏  489 B
# [ollama stderr]: verifying sha256 digest ⠇ pulling manifest
# [ollama stderr]: pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# [ollama stderr]: pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# [ollama stderr]: pulling dd084c7d92a3: 100% ▕██████████████████▏ 8.4 KB
# [ollama stderr]: pulling 3116c5225075: 100% ▕██████████████████▏   77 B
# [ollama stderr]: pulling b6ae5839783f: 100% ▕██████████████████▏  489 B
# [ollama stderr]: verifying sha256 digest ⠏ pulling manifest
# [ollama stderr]: pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# [ollama stderr]: pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# [ollama stderr]: pulling dd084c7d92a3: 100% ▕██████████████████▏ 8.4 KB
# [ollama stderr]: pulling 3116c5225075: 100% ▕██████████████████▏   77 B
# [ollama stderr]: pulling b6ae5839783f: 100% ▕██████████████████▏  489 B
# [ollama stderr]: verifying sha256 digest ⠋ pulling manifest
# [ollama stderr]: pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# [ollama stderr]: pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# [ollama stderr]: pulling dd084c7d92a3: 100% ▕██████████████████▏ 8.4 KB
# [ollama stderr]: pulling 3116c5225075: 100% ▕██████████████████▏   77 B
# [ollama stderr]: pulling b6ae5839783f: 100% ▕██████████████████▏  489 B
# [ollama stderr]: verifying sha256 digest ⠙ pulling manifest
# [ollama stderr]: pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# [ollama stderr]: pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# [ollama stderr]: pulling dd084c7d92a3: 100% ▕██████████████████▏ 8.4 KB
# [ollama stderr]: pulling 3116c5225075: 100% ▕██████████████████▏   77 B
# [ollama stderr]: pulling b6ae5839783f: 100% ▕██████████████████▏  489 B
# [ollama stderr]: verifying sha256 digest ⠹ pulling manifest
# [ollama stderr]: pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# [ollama stderr]: pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# [ollama stderr]: pulling dd084c7d92a3: 100% ▕██████████████████▏ 8.4 KB
# [ollama stderr]: pulling 3116c5225075: 100% ▕██████████████████▏   77 B
# [ollama stderr]: pulling b6ae5839783f: 100% ▕██████████████████▏  489 B
# [ollama stderr]: verifying sha256 digest ⠸ pulling manifest
# [ollama stderr]: pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# [ollama stderr]: pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# [ollama stderr]: pulling dd084c7d92a3: 100% ▕██████████████████▏ 8.4 KB
# [ollama stderr]: pulling 3116c5225075: 100% ▕██████████████████▏   77 B
# [ollama stderr]: pulling b6ae5839783f: 100% ▕██████████████████▏  489 B
# [ollama stderr]: verifying sha256 digest ⠼ pulling manifest
# [ollama stderr]: pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# [ollama stderr]: pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# [ollama stderr]: pulling dd084c7d92a3: 100% ▕██████████████████▏ 8.4 KB
# [ollama stderr]: pulling 3116c5225075: 100% ▕██████████████████▏   77 B
# [ollama stderr]: pulling b6ae5839783f: 100% ▕██████████████████▏  489 B
# [ollama stderr]: verifying sha256 digest ⠴ pulling manifest
# [ollama stderr]: pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# [ollama stderr]: pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# [ollama stderr]: pulling dd084c7d92a3: 100% ▕██████████████████▏ 8.4 KB
# [ollama stderr]: pulling 3116c5225075: 100% ▕██████████████████▏   77 B
# [ollama stderr]: pulling b6ae5839783f: 100% ▕██████████████████▏  489 B
# [ollama stderr]: verifying sha256 digest ⠦ pulling manifest
# [ollama stderr]: pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# [ollama stderr]: pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# [ollama stderr]: pulling dd084c7d92a3: 100% ▕██████████████████▏ 8.4 KB
# [ollama stderr]: pulling 3116c5225075: 100% ▕██████████████████▏   77 B
# [ollama stderr]: pulling b6ae5839783f: 100% ▕██████████████████▏  489 B
# [ollama stderr]: verifying sha256 digest ⠧ pulling manifest
# [ollama stderr]: pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# [ollama stderr]: pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# [ollama stderr]: pulling dd084c7d92a3: 100% ▕██████████████████▏ 8.4 KB
# [ollama stderr]: pulling 3116c5225075: 100% ▕██████████████████▏   77 B
# [ollama stderr]: pulling b6ae5839783f: 100% ▕██████████████████▏  489 B
# [ollama stderr]: verifying sha256 digest ⠇ pulling manifest
# [ollama stderr]: pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# [ollama stderr]: pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# [ollama stderr]: pulling dd084c7d92a3: 100% ▕██████████████████▏ 8.4 KB
# [ollama stderr]: pulling 3116c5225075: 100% ▕██████████████████▏   77 B
# [ollama stderr]: pulling b6ae5839783f: 100% ▕██████████████████▏  489 B
# [ollama stderr]: verifying sha256 digest ⠏ pulling manifest
# [ollama stderr]: pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# [ollama stderr]: pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# [ollama stderr]: pulling dd084c7d92a3: 100% ▕██████████████████▏ 8.4 KB
# [ollama stderr]: pulling 3116c5225075: 100% ▕██████████████████▏   77 B
# [ollama stderr]: pulling b6ae5839783f: 100% ▕██████████████████▏  489 B
# [ollama stderr]: verifying sha256 digest ⠋ pulling manifest
# [ollama stderr]: pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# [ollama stderr]: pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# [ollama stderr]: pulling dd084c7d92a3: 100% ▕██████████████████▏ 8.4 KB
# [ollama stderr]: pulling 3116c5225075: 100% ▕██████████████████▏   77 B
# [ollama stderr]: pulling b6ae5839783f: 100% ▕██████████████████▏  489 B
# [ollama stderr]: verifying sha256 digest ⠙ pulling manifest
# [ollama stderr]: pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# [ollama stderr]: pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# [ollama stderr]: pulling dd084c7d92a3: 100% ▕██████████████████▏ 8.4 KB
# [ollama stderr]: pulling 3116c5225075: 100% ▕██████████████████▏   77 B
# [ollama stderr]: pulling b6ae5839783f: 100% ▕██████████████████▏  489 B
# [ollama stdout]: [GIN] 2025/06/03 - 00:38:20 | 200 |          1m9s |       127.0.0.1 | POST     "/api/pull"
# [ollama stderr]: verifying sha256 digest ⠹ pulling manifest
# [ollama stderr]: pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# [ollama stderr]: pulling e0a42594d802: 100% ▕██████████████████▏  358 B
# [ollama stderr]: pulling dd084c7d92a3: 100% ▕██████████████████▏ 8.4 KB
# [ollama stderr]: pulling 3116c5225075: 100% ▕██████████████████▏   77 B
# [ollama stderr]: pulling b6ae5839783f: 100% ▕██████████████████▏  489 B
# [ollama stderr]: verifying sha256 digest
# [ollama stderr]: writing manifest
# [ollama stderr]: success
# >>> 'ollama pull gemma3:4b' finalizado com código 0.
# --- DEBUG NGROK STDERR RAW: 't=2025-06-03T00:40:00+0000 lvl=info msg="join connections" obj=join id=6a9104e4df28 l=127.0.0.1:11434 r=[2804:1530:423:b00:3ca4:fbac:dea6:e4]:60176' ---
# [ngrok stderr]: t=2025-06-03T00:40:00+0000 lvl=info msg="join connections" obj=join id=6a9104e4df28 l=127.0.0.1:11434 r=[2804:1530:423:b00:3ca4:fbac:dea6:e4]:60176
# [ollama stdout]: [GIN] 2025/06/03 - 00:40:00 | 403 |      41.739µs | 2804:1530:423:b00:3ca4:fbac:dea6:e4 | HEAD     "/"

# %%
# !curl --version
# !python3 --version
# !pip3 --version

# !sudo apt-get update
# !sudo apt-get install -y pciutils
# !sudo apt-get install -y lspci

# !curl -fsSL https://ollama.com/install.sh | sh

# !useradd -r -s /bin/false -m -d /usr/share/ollama ollama
# !groupadd ollama # Pode já existir
# !usermod -a -G ollama $(whoami) # Adiciona seu usuário atual ao grupo ollama
# !chown -R ollama:ollama /usr/share/ollama # Garante permissões no diretório home do usuário ollama
# Out:
# curl 7.81.0 (x86_64-pc-linux-gnu) libcurl/7.81.0 OpenSSL/3.0.2 zlib/1.2.11 brotli/1.0.9 zstd/1.4.8 libidn2/2.3.2 libpsl/0.21.0 (+libidn2/2.3.2) libssh/0.9.6/openssl/zlib nghttp2/1.43.0 librtmp/2.3 OpenLDAP/2.5.17
# Release-Date: 2022-01-05
# Protocols: dict file ftp ftps gopher gophers http https imap imaps ldap ldaps mqtt pop3 pop3s rtmp rtsp scp sftp smb smbs smtp smtps telnet tftp
# Features: alt-svc AsynchDNS brotli GSS-API HSTS HTTP2 HTTPS-proxy IDN IPv6 Kerberos Largefile libz NTLM NTLM_WB PSL SPNEGO SSL TLS-SRP UnixSockets zstd
# Python 3.11.12
# pip 24.1.2 from /usr/local/lib/python3.11/dist-packages/pip (python 3.11)
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:6 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# pciutils is already the newest version (1:3.7.0-6).
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# E: Unable to locate package lspci
# >>> Cleaning up old version at /usr/local/lib/ollama
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ######################################################################## 100.0%
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# >>> NVIDIA GPU installed.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.
# useradd: user 'ollama' already exists
# groupadd: group 'ollama' already exists

# %%
# !nohup ollama serve > /dev/null 2>&1 &

# %%
# !ollama pull gemma3:4b

# %%
# !ollama list
# Out:
# NAME         ID              SIZE      MODIFIED
# gemma3:4b    a2af6cc3eb7f    3.3 GB    4 seconds ago

# %%
# !ollama run gemma3:4b
# Out:
# >>> Send a message (/? for help)oi,
# ... tudo
# ...  bem
# ... ?
# Oi! Tudo bem por aqui, e com você? 😊 Como posso te ajudar hoje?
#
#
# >>> Send a message (/? for help)agor
# ... a vc
# ...  est
# ... a mu
# ... ito
# ... mais
# ...  rap
# ... ida,
# ...  que
# ...  bom
# ...
# Que bom que você percebeu! A equipe do Google tem feito muitos aprimoramentos na minha velocidade e inteligência. É ótimo saber que você está notando a diferença! 😊
#
# O que você gostaria de fazer agora?
#
#
# >>> Send a message (/? for help)/bue
# ...
# Unknown command '/bue'. Type /? for help
# >>> Send a message (/? for help)/bye
# ...
